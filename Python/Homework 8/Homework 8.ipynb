# %% [markdown]
# # Задание 1
# Напишите функцию, которая возвращает название валюты (поле ‘Name’) с максимальным значением курса с помощью сервиса www.cbr-xml-daily.ru...ly_json.js

# %%
import requests

def funct_():
    a = requests.get('https://www.cbr-xml-daily.ru/daily_json.js')
    for i in a.json()['Valute']:
        name = i
        now = a.json()['Valute'][name]['Value']
        prev = a.json()['Valute'][name]['Previous']
        print (name, max(now,prev))
    
funct_()
# Out:
# AUD 54.8376
# AZN 42.5697
# GBP 101.1334
# AMD 14.2094
# BYN 28.5727
# BGN 44.1497
# BRL 14.6844
# HUF 24.6969
# HKD 93.1484
# DKK 11.6119
# USD 72.326
# EUR 86.3283
# INR 97.4639
# KZT 16.876
# CAD 58.8495
# KGS 85.4157
# CNY 11.1806
# MDL 40.1477
# NOK 85.0824
# PLN 19.1197
# RON 17.5336
# XDR 103.322
# SGD 53.806
# TJS 63.416
# TRY 83.4027
# TMT 20.6941
# UZS 68.4136
# UAH 26.4036
# CZK 34.0198
# SEK 85.417
# CHF 78.7093
# ZAR 50.975
# KRW 63.9956
# JPY 65.2438

# %% [markdown]
# # Задание 2
# Добавьте в класс Rate параметр diff (со значениями True или False), который в случае значения True в методах курсов валют (eur, usd итд) будет возвращать не курс валюты, а изменение по сравнению в прошлым значением. Считайте, self.diff будет принимать значение True только при возврате значения курса. При отображении всей информации о валюте он не используется.

# %%
import requests
import math

class Rate: 
    def Met_(self, diff=False):
        self.diff = diff
        a = requests.get('https://www.cbr-xml-daily.ru/daily_json.js')
        for i in a.json()['Valute']:
            name = i
            now = a.json()['Valute'][name]['Value']
            prev = a.json()['Valute'][name]['Previous']
            if self.diff:
                print (f'Разница курса валюты {name} {prev-now}')
            else:
                print(f'Текущий курс валюты {name}: {now}')
        print('\n')

a = Rate()
a.Met_(True)           
a.Met_()
# Out:
# Разница курса валюты AUD 0.0033000000000029672
# Разница курса валюты AZN 0.09209999999999496
# Разница курса валюты GBP 0.767399999999995
# Разница курса валюты AMD -0.0835000000000008
# Разница курса валюты BYN 0.02020000000000266
# Разница курса валюты BGN 0.08750000000000568
# Разница курса валюты BRL -0.12160000000000082
# Разница курса валюты HUF 0.14699999999999847
# Разница курса валюты HKD 0.1681999999999988
# Разница курса валюты DKK 0.021399999999999864
# Разница курса валюты USD 0.1565999999999974
# Разница курса валюты EUR 0.13639999999999475
# Разница курса валюты INR 0.18739999999999668
# Разница курса валюты KZT -0.00870000000000104
# Разница курса валюты CAD 0.19899999999999807
# Разница курса валюты KGS 0.19939999999999714
# Разница курса валюты CNY -0.00730000000000075
# Разница курса валюты MDL 0.1203000000000003
# Разница курса валюты NOK 0.02610000000001378
# Разница курса валюты PLN -0.03780000000000072
# Разница курса валюты RON 0.04100000000000037
# ...

# %% [markdown]
# # Задание 3
# Напишите класс Designer, который учитывает количество международных премий. Подсказки в коде занятия в разделе “Домашнее задание задача 3”.
#
# Комментарий по классу Designer такой:
# Напишите класс Designer, который учитывает количество международных премий для дизайнеров (из презентации: “Повышение на 1 грейд за каждые 7 баллов. Получение международной премии – это +2 балла”). Считайте, что при выходе на работу сотрудник уже имеет две премии и их количество не меняется со стажем (конечно если хотите это можно вручную менять).
#
# Класс Designer пишется по аналогии с классом Developer из материалов занятия.

# %%
from Python_class import Employee

class Designer(Employee):
    def __init__(self,name,seniority=0, prizes = 2):
        super().__init__(name, seniority)
        self.prizes = prizes
        self.scores_for_up = self.prizes*2
    
    def take_prize(self):
        self.prizes+=1
        self.scores_for_up+=2
        print(f'\nСотруднику {self.name} выдана 1 премия. Всего премий: {self.prizes}')
        
        
        if 7 in range(self.scores_for_up+1):
            self.scores_for_up -= 7
            self.grade_up()
    
employee = Designer('Юлия')

employee.take_prize()
employee.publish_grade()

employee.take_prize()
employee.publish_grade()

employee.take_prize()
employee.publish_grade()

employee.take_prize()
employee.publish_grade()

employee.take_prize()
employee.publish_grade()

employee.take_prize()
employee.publish_grade()
# Out:
# Сотруднику Юлия выдана 1 премия. Всего премий: 3
# У сотрудника Юлия грейд 1
#
# Сотруднику Юлия выдана 1 премия. Всего премий: 4
# У сотрудника Юлия грейд 2
#
# Сотруднику Юлия выдана 1 премия. Всего премий: 5
# У сотрудника Юлия грейд 2
#
# Сотруднику Юлия выдана 1 премия. Всего премий: 6
# У сотрудника Юлия грейд 2
#
# Сотруднику Юлия выдана 1 премия. Всего премий: 7
# У сотрудника Юлия грейд 3
#
# Сотруднику Юлия выдана 1 премия. Всего премий: 8
# У сотрудника Юлия грейд 3
