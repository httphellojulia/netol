# %% [markdown]
# # Задание 1
# Напишите функцию, которая классифицирует фильмы из материалов занятия по следующим правилам:
# - оценка 2 и меньше - низкий рейтинг
# - оценка 4 и меньше - средний рейтинг
# - оценка 4.5 и 5 - высокий рейтинг
#
# Результат классификации запишите в столбец class

# %%
import pandas as pd

data = pd.read_csv('ml-latest-small_2/ratings.csv')

def funct_(rating):
    if rating <= 2:
        return 'низкий рейтинг'
    elif rating <= 4:
        return 'средний рейтинг'
    elif rating >= 4.5:
        return 'высокий рейтинг'
    else:
        return 'ошибка в данных рейтинга'
    
data['class'] = data['rating'].apply(funct_)

data.head(30)
# Out:
#     userId  movieId  rating   timestamp            class
# 0        1       31     2.5  1260759144  средний рейтинг
# 1        1     1029     3.0  1260759179  средний рейтинг
# 2        1     1061     3.0  1260759182  средний рейтинг
# 3        1     1129     2.0  1260759185   низкий рейтинг
# 4        1     1172     4.0  1260759205  средний рейтинг
# 5        1     1263     2.0  1260759151   низкий рейтинг
# 6        1     1287     2.0  1260759187   низкий рейтинг
# 7        1     1293     2.0  1260759148   низкий рейтинг
# 8        1     1339     3.5  1260759125  средний рейтинг
# 9        1     1343     2.0  1260759131   низкий рейтинг
# 10       1     1371     2.5  1260759135  средний рейтинг
# 11       1     1405     1.0  1260759203   низкий рейтинг
# 12       1     1953     4.0  1260759191  средний рейтинг
# 13       1     2105     4.0  1260759139  средний рейтинг
# 14       1     2150     3.0  1260759194  средний рейтинг
# ...

# %% [markdown]
# # Задание 2
# Используем файл keywords.csv.
#
# Необходимо написать гео-классификатор, который каждой строке сможет выставить географическую принадлежность определенному региону. Т. е. если поисковый запрос содержит название города региона, то в столбце ‘region’ пишется название этого региона. Если поисковый запрос не содержит названия города, то ставим ‘undefined’.
#
# Правила распределения по регионам Центр, Северо-Запад и Дальний Восток:
#
# Результат классификации запишите в отдельный столбец region.

# %%
import pandas as pd

data = pd.read_csv('ml-latest-small_2/keywords.csv')

geo_data = {
'Центр': ['москва', 'тула', 'ярославль'],
'Северо-Запад': ['петербург', 'псков', 'мурманск',],
'Дальний Восток': ['владивосток', 'сахалин', 'хабаровск']
}


def funct_(search):
    for i,x in enumerate(geo_data.values()):
        for values in x:
            if values[0:-1] in search.lower():
                return tuple(geo_data.keys())[i]
    return 'undefined'

data['region'] = data['keyword'].apply(funct_)

data[(data.region == 'Центр') | (data.region == 'Северо-Запад')| (data.region == 'Дальний Восток')]
# Out:
#                                     keyword   shows        region
# 127                            авито москва  979292         Центр
# 143                              эхо москвы  889657         Центр
# 197                         погода в москве  745745         Центр
# 370                авито ру санкт петербург  425134  Северо-Запад
# 414              погода в москве на 14 дней  400914         Центр
# ...                                     ...     ...           ...
# 99634  северпост новости мурманской области    3606  Северо-Запад
# 99808     полармед мурманск запись на прием    3719  Северо-Запад
# 99849                  малахитовая шкатулка    3650         Центр
# 99890                   яндекс метро москва    4548         Центр
# 99922                     авто ру ярославль    3712         Центр
#
# [1217 rows x 3 columns]
